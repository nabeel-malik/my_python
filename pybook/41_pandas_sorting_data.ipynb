# %% [markdown]
# # Pandas - Sorting data

# %% [markdown]
# ## Table of contents
#
# * [Dataframe sorting](#Dataframe-sorting)
#     * [Single-level sorting: `DataFrame.sort_values(by=<column>, ascending=True, inplace=False)`](#Single-level-sorting:-DataFrame.sort_values(by=<column>,-ascending=True,-inplace=False))
#     * [Multi-level sorting: `DataFrame.sort_values(by=[column_list], ascending=True, inplace=False)`](#Multi-level-sorting:-DataFrame.sort_values(by=[column_list],-ascending=True,-inplace=False))
#     * [Multi-level & multi-direction sorting: `DataFrame.sort_values(by=[column_list], ascending=[boolean_list], inplace=False)`](#Multi-level-&-multi-direction-sorting:-DataFrame.sort_values(by=[column_list],-ascending=[boolean_list],-inplace=False))
# * [Series sorting: `Series.sort_values(ascending=True, inplace=False)` method](#Series-sorting:-Series.sort_values(ascending=True,-inplace=False)-method)
# * [Now, let's go back to the stack overflow dataset and work with it](#Now,-let's-go-back-to-the-stack-overflow-dataset-and-work-with-it)
#     * [`DataFrame.nlargest(<n>, <column>)` and `Series.nlargest(<n>)` methods](#DataFrame.nlargest(<n>,-<column>)-and-Series.nlargest(<n>)-methods)
#     * [`DataFrame.nsmallest(<n>, <column>)` and `Series.nsmallest(<n>)` methods](#DataFrame.nsmallest(<n>,-<column>)-and-Series.nsmallest(<n>)-methods)

# %% [markdown]
# ***

# %%
people = {
    "first": ["Nabeel", "Jane", "John", "Adam"],
    "last": ["Malik", "Doe", "Doe", "Doe"],
    "email": ["nabeel_malik@email.com", "jane_doe@email.com", "john_doe@email.com", "adam_doe@email.com"]
}

# %%
import pandas as pd
df_ppl = pd.DataFrame(people)

# %%
df_ppl
# Out:
#     first   last                   email
# 0  Nabeel  Malik  nabeel_malik@email.com
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 3    Adam    Doe      adam_doe@email.com

# %% [markdown]
# ## Dataframe sorting

# %% [markdown]
# ### Single-level sorting: `DataFrame.sort_values(by=<column>, ascending=True, inplace=False)`

# %% [markdown]
# To sort by *'last'* names in *ascending* order:

# %%
df_ppl
# Out:
#     first   last                   email
# 0  Nabeel  Malik  nabeel_malik@email.com
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 3    Adam    Doe      adam_doe@email.com

# %%
df_ppl.sort_values(by='last')
# Out:
#     first   last                   email
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 3    Adam    Doe      adam_doe@email.com
# 0  Nabeel  Malik  nabeel_malik@email.com

# %% [markdown]
# To sort by *'last'* names in *descending* order:

# %%
df_ppl.sort_values(by='last', ascending=False)
# Out:
#     first   last                   email
# 0  Nabeel  Malik  nabeel_malik@email.com
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 3    Adam    Doe      adam_doe@email.com

# %% [markdown]
# ### Multi-level sorting: `DataFrame.sort_values(by=[column_list], ascending=True, inplace=False)`

# %% [markdown]
# For *multi-level sorting* in *ascending* order:

# %%
df_ppl.sort_values(by=['last', 'first'])
# Out:
#     first   last                   email
# 3    Adam    Doe      adam_doe@email.com
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 0  Nabeel  Malik  nabeel_malik@email.com

# %% [markdown]
# ### Multi-level & multi-direction sorting: `DataFrame.sort_values(by=[column_list], ascending=[boolean_list], inplace=False)`

# %% [markdown]
# For *multi-level & multi-direction sorting*:

# %%
df_ppl.sort_values(by=['last', 'first'], ascending=[True, False])
# Out:
#     first   last                   email
# 2    John    Doe      john_doe@email.com
# 1    Jane    Doe      jane_doe@email.com
# 3    Adam    Doe      adam_doe@email.com
# 0  Nabeel  Malik  nabeel_malik@email.com

# %%
df_ppl
# Out:
#     first   last                   email
# 0  Nabeel  Malik  nabeel_malik@email.com
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 3    Adam    Doe      adam_doe@email.com

# %% [markdown]
# Note: To sort the `DataFrame` inplace with the `.sort_values()` method, we need to set `inplace=True`.

# %%
df_ppl.sort_values(by=['last', 'first'], inplace=True)

# %%
df_ppl
# Out:
#     first   last                   email
# 3    Adam    Doe      adam_doe@email.com
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 0  Nabeel  Malik  nabeel_malik@email.com

# %% [markdown]
# ## `DataFrame.sort_index()` method

# %% [markdown]
# Now, if we want to reset the sorting of the `DataFrame` to the way it originally was, i.e. *sorted by indexes*, we can use the `DataFrame.sort_index()` method:

# %%
df_ppl
# Out:
#     first   last                   email
# 3    Adam    Doe      adam_doe@email.com
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 0  Nabeel  Malik  nabeel_malik@email.com

# %%
df_ppl.sort_index(inplace=True)

# %%
df_ppl
# Out:
#     first   last                   email
# 0  Nabeel  Malik  nabeel_malik@email.com
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 3    Adam    Doe      adam_doe@email.com

# %% [markdown]
# ## Series sorting: `Series.sort_values(ascending=True, inplace=False)` method

# %% [markdown]
# The only difference between `Series.sort_values()` and `DataFrame.sort_values()` methods is that `Series.sort_values()` DOES NOT have the `inplace=` argument, and needs to be reassigned to store changes.

# %%
df_ppl
# Out:
#     first   last                   email
# 0  Nabeel  Malik  nabeel_malik@email.com
# 1    Jane    Doe      jane_doe@email.com
# 2    John    Doe      john_doe@email.com
# 3    Adam    Doe      adam_doe@email.com

# %%
series_ppl = df_ppl['first'].sort_values()

# %%
series_ppl
# Out:
# 3      Adam
# 1      Jane
# 2      John
# 0    Nabeel
# Name: first, dtype: object

# %% [markdown]
# ***

# %% [markdown]
# ## Now, let's go back to the stack overflow dataset and work with it

# %%
df = pd.read_csv('work_directory/pandas/data/survey_results_public.csv', index_col='Respondent')
df_schema = pd.read_csv('work_directory/pandas/data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %% [markdown]
# Let's sort the `DataFrame` for survey results by *'Country'* in an *ascending* order:

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country'].head(50)
# Out:
# Respondent
# 40000    Afghanistan
# 33178    Afghanistan
# 29045    Afghanistan
# 8149     Afghanistan
# 12310    Afghanistan
# 7353     Afghanistan
# 7085     Afghanistan
# 29736    Afghanistan
# 722      Afghanistan
# 6417     Afghanistan
# 26340    Afghanistan
# 37802    Afghanistan
# 10746    Afghanistan
# 39258    Afghanistan
# 28638    Afghanistan
# 22450    Afghanistan
# 25100        Albania
# 2332         Albania
# 21700        Albania
# 25109        Albania
# 20414        Albania
# 20142        Albania
# 18869        Albania
# 18837        Albania
# 18295        Albania
# 38928        Albania
# 25589        Albania
# 28873        Albania
# 26191        Albania
# 27637        Albania
# 18128        Albania
# 29164        Albania
# 29415        Albania
# 33385        Albania
# 33593        Albania
# 34211        Albania
# 36028        Albania
# 36574        Albania
# 37363        Albania
# 38308        Albania
# 1954         Albania
# 16157        Albania
# 21754        Albania
# 39106        Albania
# 10527        Albania
# 15993        Albania
# 9441         Albania
# 10935        Albania
# 9270         Albania
# 9229         Albania
# Name: Country, dtype: object

# %% [markdown]
# Now, let's say we want the following *multi-level sorting*:
# - Level 1: *'Country'* in *ascending* order
# - Level 2: *'ConvertedComp'* in *descending* order (to have the highest salaries, for each country, at the top)

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 40000       Afghanistan            NaN
# 33178       Afghanistan            NaN
# 29045       Afghanistan            NaN
# 8149        Afghanistan         1596.0
# 12310       Afghanistan            NaN
# 7353        Afghanistan            NaN
# 7085        Afghanistan        14364.0
# 29736       Afghanistan         1116.0
# 722         Afghanistan            0.0
# 6417        Afghanistan            NaN
# 26340       Afghanistan            NaN
# 37802       Afghanistan            NaN
# 10746       Afghanistan         3996.0
# 39258       Afghanistan        19152.0
# 28638       Afghanistan            0.0
# 22450       Afghanistan         7980.0
# 25100           Albania         9936.0
# 2332            Albania        22080.0
# 21700           Albania        11040.0
# 25109           Albania            NaN
# 20414           Albania            NaN
# 20142           Albania            NaN
# 18869           Albania         7728.0
# 18837           Albania            NaN
# 18295           Albania        13800.0
# 38928           Albania        24729.0
# 25589           Albania         4416.0
# 28873           Albania        34368.0
# 26191           Albania            NaN
# 27637           Albania         9624.0
# 18128           Albania            NaN
# 29164           Albania        13752.0
# 29415           Albania            NaN
# 33385           Albania            NaN
# 33593           Albania         5520.0
# 34211           Albania         5496.0
# 36028           Albania         8832.0
# 36574           Albania        23952.0
# 37363           Albania            NaN
# 38308           Albania       187668.0
# 1954            Albania        11040.0
# 16157           Albania            NaN
# 21754           Albania            NaN
# 39106           Albania            NaN
# 10527           Albania            NaN
# 15993           Albania         8832.0
# 9441            Albania            NaN
# 10935           Albania            NaN
# 9270            Albania        74474.0
# 9229            Albania            NaN

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 39258       Afghanistan        19152.0
# 7085        Afghanistan        14364.0
# 22450       Afghanistan         7980.0
# 10746       Afghanistan         3996.0
# 8149        Afghanistan         1596.0
# 29736       Afghanistan         1116.0
# 722         Afghanistan            0.0
# 28638       Afghanistan            0.0
# 40000       Afghanistan            NaN
# 33178       Afghanistan            NaN
# 29045       Afghanistan            NaN
# 12310       Afghanistan            NaN
# 7353        Afghanistan            NaN
# 6417        Afghanistan            NaN
# 26340       Afghanistan            NaN
# 37802       Afghanistan            NaN
# 38308           Albania       187668.0
# 3787            Albania       114550.0
# 9270            Albania        74474.0
# 6716            Albania        60000.0
# 10303           Albania        57300.0
# 28873           Albania        34368.0
# 38928           Albania        24729.0
# 36574           Albania        23952.0
# 2332            Albania        22080.0
# 12265           Albania        18768.0
# 18295           Albania        13800.0
# 29164           Albania        13752.0
# 21700           Albania        11040.0
# 1954            Albania        11040.0
# 13385           Albania        10596.0
# 25100           Albania         9936.0
# 27637           Albania         9624.0
# 36028           Albania         8832.0
# 15993           Albania         8832.0
# 18869           Albania         7728.0
# 15374           Albania         7728.0
# 11549           Albania         6624.0
# 33593           Albania         5520.0
# 34211           Albania         5496.0
# 25589           Albania         4416.0
# 25109           Albania            NaN
# 20414           Albania            NaN
# 20142           Albania            NaN
# 18837           Albania            NaN
# 26191           Albania            NaN
# 18128           Albania            NaN
# 29415           Albania            NaN
# 33385           Albania            NaN
# 37363           Albania            NaN

# %% [markdown]
# ### `DataFrame.nlargest(<n>, <column>)` and `Series.nlargest(<n>)` methods

# %% [markdown]
# Now, instead of doing all the sorting, as above, if we simply want to view the *10 largest salaries* in our `DataFrame`, we can use:
# - `DataFrame.nlargest()` **method** to view the entire survey results for the *10 largest salaries*, or
# - `Series.nlargest()` **method** to view only the *values* of the *10 largest salaries*

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 25983       I am a developer by profession      Yes
# 22013       I am a developer by profession      Yes
# 28243       I am a developer by profession      Yes
# 32250       I am a developer by profession      Yes
# 15528       I am a developer by profession       No
# 34938       I am a developer by profession      Yes
# 539         I am a developer by profession       No
# 3873        I am a developer by profession      Yes
# 12625       I am a developer by profession      Yes
# 36336       I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# 22013                                                   Never
# 28243                              Once a month or more often
# 32250                              Once a month or more often
# 15528                                                   Never
# 34938                                                   Never
# 539         Less than once a month but more than once per ...
# 3873                                                    Never
# 12625                                                   Never
# 36336                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 25983       OSS is, on average, of HIGHER quality than pro...
# 22013       The quality of OSS and closed source software ...
# 28243       OSS is, on average, of HIGHER quality than pro...
# 32250       The quality of OSS and closed source software ...
# 15528       OSS is, on average, of HIGHER quality than pro...
# 34938       The quality of OSS and closed source software ...
# 539         OSS is, on average, of HIGHER quality than pro...
# 3873        OSS is, on average, of HIGHER quality than pro...
# 12625       OSS is, on average, of HIGHER quality than pro...
# 36336       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment        Country  \
# Respondent
# 25983                                      Employed full-time         Canada
# 22013                                      Employed full-time          India
# 28243       Independent contractor, freelancer, or self-em...          India
# 32250                                      Employed full-time    Switzerland
# 15528                                      Employed full-time  United States
# 34938                                      Employed full-time  United States
# 539                                        Employed full-time  United States
# 3873                                       Employed full-time  United States
# 12625                                      Employed full-time  United States
# 36336                                      Employed full-time  United States
#
#            Student                                            EdLevel  \
# Respondent
# 25983           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 22013           No                 Professional degree (JD, MD, etc.)
# 28243           No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 32250           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 15528           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 34938           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 539             No  Some college/university study without earning ...
# 3873            No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 12625           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 36336           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 25983       Computer science, computer engineering, or sof...
# 22013       A natural science (ex. biology, chemistry, phy...
# 28243       Computer science, computer engineering, or sof...
# 32250       Computer science, computer engineering, or sof...
# 15528       Computer science, computer engineering, or sof...
# 34938                           Web development or web design
# 539                                 Mathematics or statistics
# 3873        Computer science, computer engineering, or sof...
# 12625       Computer science, computer engineering, or sof...
# 36336       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 25983       Received on-the-job training in software devel...
# 22013       Taken an online course in programming or softw...
# 28243       Taken an online course in programming or softw...
# 32250       Taken a part-time in-person course in programm...
# 15528       Taken an online course in programming or softw...
# 34938       Taken an online course in programming or softw...
# 539         Taken an online course in programming or softw...
# 3873        Taught yourself a new language, framework, or ...
# 12625       Taught yourself a new language, framework, or ...
# 36336       Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 25983       10,000 or more employees
# 22013                  2-9 employees
# 28243                  2-9 employees
# 32250                  2-9 employees
# 15528           100 to 499 employees
# 34938           100 to 499 employees
# 539         10,000 or more employees
# 3873        10,000 or more employees
# 12625             20 to 99 employees
# 36336             20 to 99 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 25983                                   Developer, full-stack         8
# 22013       Academic researcher;Data scientist or machine ...         3
# 28243       Developer, back-end;Developer, full-stack;Deve...        25
# 32250       Academic researcher;Data scientist or machine ...        16
# 15528                  Developer, front-end;Developer, mobile         6
# 34938       Database administrator;Designer;Developer, ful...        10
# 539         Data scientist or machine learning specialist;...        22
# 3873        Data scientist or machine learning specialist;...         5
# 12625                                   Developer, full-stack         8
# 36336                                   Developer, full-stack         7
#
#            Age1stCode YearsCodePro                           CareerSat  \
# Respondent
# 25983              16            2                      Very satisfied
# 22013              26            3                      Very satisfied
# 28243               9           14  Neither satisfied nor dissatisfied
# 32250              14            9                  Slightly satisfied
# 15528              15            2                      Very satisfied
# 34938               6           10                  Slightly satisfied
# 539                14           20                      Very satisfied
# 3873               13            1               Slightly dissatisfied
# 12625              16            5                  Slightly satisfied
# 36336              16            3                  Slightly satisfied
#
#                                         JobSat            MgrIdiot MgrMoney  \
# Respondent
# 25983                           Very satisfied  Somewhat confident       No
# 22013                           Very satisfied                 NaN      NaN
# 28243       Neither satisfied nor dissatisfied                 NaN      NaN
# 32250                           Very satisfied                 NaN      NaN
# 15528                       Slightly satisfied      Very confident      Yes
# 34938                        Very dissatisfied  Somewhat confident      Yes
# 539                         Slightly satisfied      Very confident      Yes
# 3873                     Slightly dissatisfied      Very confident       No
# 12625                       Slightly satisfied  Somewhat confident      Yes
# 36336                       Slightly satisfied  Somewhat confident      Yes
#
#              MgrWant                                            JobSeek  \
# Respondent
# 25983             No  I’m not actively looking, but I am open to new...
# 22013            NaN       I am not interested in new job opportunities
# 28243            NaN  I’m not actively looking, but I am open to new...
# 32250            NaN  I’m not actively looking, but I am open to new...
# 15528       Not sure  I’m not actively looking, but I am open to new...
# 34938       Not sure                    I am actively looking for a job
# 539               No  I’m not actively looking, but I am open to new...
# 3873              No  I’m not actively looking, but I am open to new...
# 12625       Not sure  I’m not actively looking, but I am open to new...
# 36336       Not sure  I’m not actively looking, but I am open to new...
#
#                      LastHireDate  \
# Respondent
# 25983               3-4 years ago
# 22013               3-4 years ago
# 28243               1-2 years ago
# 32250               1-2 years ago
# 15528               1-2 years ago
# 34938       More than 4 years ago
# 539                 1-2 years ago
# 3873                1-2 years ago
# 12625        Less than a year ago
# 36336               1-2 years ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 25983       Solve a brain-teaser style puzzle;Interview wi...       No
# 22013       Write code by hand (e.g., on a whiteboard);Com...       No
# 28243       Interview with people in peer roles;Interview ...      Yes
# 32250       Write any code;Write code by hand (e.g., on a ...      Yes
# 15528       Complete a take-home project;Interview with pe...      Yes
# 34938       Write any code;Write code by hand (e.g., on a ...      Yes
# 539         Write any code;Complete a take-home project;In...      Yes
# 3873        Interview with people in senior / management r...      Yes
# 12625       Solve a brain-teaser style puzzle;Interview wi...       No
# 36336       Interview with people in peer roles;Interview ...       No
#
#                                                    JobFactors  \
# Respondent
# 25983       Remote work options;Opportunities for professi...
# 22013       Financial performance or funding status of the...
# 28243       Financial performance or funding status of the...
# 32250       Office environment or company culture;Opportun...
# 15528       Specific department or team I'd be working on;...
# 34938       Financial performance or funding status of the...
# 539         Languages, frameworks, and other technologies ...
# 3873        Financial performance or funding status of the...
# 12625       Industry that I'd be working in;Languages, fra...
# 36336       Remote work options;How widely used or impactf...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 25983        My job status changed (promotion, new job, etc.)            USD
# 22013       Something else changed (education, award, medi...            USD
# 28243       I heard about a job opportunity (from a recrui...            USD
# 32250       Something else changed (education, award, medi...            USD
# 15528       I heard about a job opportunity (from a recrui...            USD
# 34938                        I was preparing for a job search            USD
# 539                          I was preparing for a job search            USD
# 3873        I heard about a job opportunity (from a recrui...            USD
# 12625                        I was preparing for a job search            USD
# 36336                        I was preparing for a job search            USD
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 25983       United States dollar    65500.0   Weekly      2000000.0
# 22013       United States dollar  1500000.0   Weekly      2000000.0
# 28243       United States dollar  2000000.0   Yearly      2000000.0
# 32250       United States dollar   200000.0  Monthly      2000000.0
# 15528       United States dollar    85000.0   Weekly      2000000.0
# 34938       United States dollar    50000.0   Weekly      2000000.0
# 539         United States dollar   140000.0   Weekly      2000000.0
# 3873        United States dollar    90000.0   Weekly      2000000.0
# 12625       United States dollar    45000.0   Weekly      2000000.0
# 36336       United States dollar    75000.0   Weekly      2000000.0
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 25983              45.0  There is a schedule and/or spec (made by me or...
# 22013              50.0  There's no schedule or spec; I work on what se...
# 28243              20.0  There is a schedule and/or spec (made by me or...
# 32250              50.0  There is a schedule and/or spec (made by me or...
# 15528              40.0  There is a schedule and/or spec (made by me or...
# 34938              45.0  There is a schedule and/or spec (made by me or...
# 539                50.0  There is a schedule and/or spec (made by me or...
# 3873               40.0  There is a schedule and/or spec (made by me or...
# 12625              40.0  There's no schedule or spec; I work on what se...
# 36336              40.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 25983       Being tasked with non-development work;Meeting...
# 22013       Inadequate access to necessary tools;Meetings;...
# 28243       Being tasked with non-development work;Not eno...
# 32250       Being tasked with non-development work;Non-wor...
# 15528       Lack of support from management;Not enough peo...
# 34938       Lack of support from management;Not enough peo...
# 539         Being tasked with non-development work;Non-wor...
# 3873        Being tasked with non-development work;Distrac...
# 12625       Being tasked with non-development work;Distrac...
# 36336                  Being tasked with non-development work
#
#                                                    WorkRemote WorkLoc  \
# Respondent
# 25983                                   A few days each month  Office
# 22013       All or almost all the time (I'm full-time remote)    Home
# 28243       All or almost all the time (I'm full-time remote)  Office
# 32250       All or almost all the time (I'm full-time remote)    Home
# 15528                                   A few days each month  Office
# 34938       Less than half the time, but at least one day ...    Home
# 539                                     A few days each month  Office
# 3873                                    A few days each month  Office
# 12625                        Less than once per month / Never  Office
# 36336                        Less than once per month / Never  Office
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 25983                      Average  Yes, because I see value in code review
# 22013       A little below average  Yes, because I see value in code review
# 28243            Far above average  Yes, because I see value in code review
# 32250            Far above average  Yes, because I see value in code review
# 15528       A little above average  Yes, because I see value in code review
# 34938                      Average  Yes, because I see value in code review
# 539         A little above average  Yes, because I see value in code review
# 3873             Far above average  Yes, because I see value in code review
# 12625       A little above average  Yes, because I see value in code review
# 36336       A little above average  Yes, because I see value in code review
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 25983              2.0                      Yes, it's part of our process
# 22013             10.0                      Yes, it's part of our process
# 28243              NaN                                                NaN
# 32250             20.0                      Yes, it's part of our process
# 15528              8.0                      Yes, it's part of our process
# 34938             10.0                          No, but I think we should
# 539               10.0  Yes, it's not part of our process but the deve...
# 3873               1.0                      Yes, it's part of our process
# 12625              5.0                          No, but I think we should
# 36336              1.0                          No, but I think we should
#
#                                                   PurchaseHow  \
# Respondent
# 25983       Developers and management have nearly equal in...
# 22013       Developers typically have the most influence o...
# 28243                                                     NaN
# 32250       Developers typically have the most influence o...
# 15528       Developers and management have nearly equal in...
# 34938       Developers and management have nearly equal in...
# 539         The CTO, CIO, or other management purchase new...
# 3873        The CTO, CIO, or other management purchase new...
# 12625       Developers and management have nearly equal in...
# 36336       Developers and management have nearly equal in...
#
#                                 PurchaseWhat  \
# Respondent
# 25983          I have little or no influence
# 22013       I have a great deal of influence
# 28243                                    NaN
# 32250       I have a great deal of influence
# 15528                  I have some influence
# 34938                  I have some influence
# 539            I have little or no influence
# 3873           I have little or no influence
# 12625                  I have some influence
# 36336                  I have some influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 25983       Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 22013       Assembly;Bash/Shell/PowerShell;C;C++;Java;Java...
# 28243               C++;C#;Java;JavaScript;Objective-C;Python
# 32250         C#;Go;HTML/CSS;JavaScript;Python;SQL;TypeScript
# 15528           Bash/Shell/PowerShell;C#;Java;Objective-C;SQL
# 34938       C#;HTML/CSS;Java;JavaScript;Objective-C;PHP;SQ...
# 539               Bash/Shell/PowerShell;JavaScript;Python;SQL
# 3873         Bash/Shell/PowerShell;HTML/CSS;JavaScript;Python
# 12625           Bash/Shell/PowerShell;HTML/CSS;JavaScript;SQL
# 36336                                         Java;JavaScript
#
#                                        LanguageDesireNextYear  \
# Respondent
# 25983       Bash/Shell/PowerShell;C#;F#;Python;SQL;TypeScript
# 22013                                            Python;Swift
# 28243                                                C;C++;C#
# 32250                                  C#;HTML/CSS;JavaScript
# 15528                                            Kotlin;Swift
# 34938                                                  C++;Go
# 539                           Go;JavaScript;Python;TypeScript
# 3873         Bash/Shell/PowerShell;HTML/CSS;JavaScript;Python
# 12625            Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript
# 36336                                                     NaN
#
#                                          DatabaseWorkedWith  \
# Respondent
# 25983                            Microsoft SQL Server;MySQL
# 22013                 Cassandra;Microsoft SQL Server;Oracle
# 28243                                     PostgreSQL;SQLite
# 32250                          DynamoDB;Elasticsearch;Redis
# 15528                                          MySQL;SQLite
# 34938       MariaDB;Microsoft SQL Server;MySQL;Redis;SQLite
# 539                                       PostgreSQL;SQLite
# 3873                                               Firebase
# 12625                                         MongoDB;MySQL
# 36336                                                 MySQL
#
#                                DatabaseDesireNextYear  \
# Respondent
# 25983                      Microsoft SQL Server;MySQL
# 22013                                       Cassandra
# 28243                                          SQLite
# 32250                          DynamoDB;Elasticsearch
# 15528                                        Firebase
# 34938                                             NaN
# 539         Couchbase;MongoDB;PostgreSQL;Redis;SQLite
# 3873                            Firebase;MySQL;SQLite
# 12625                Elasticsearch;MongoDB;PostgreSQL
# 36336                                         MongoDB
#
#                                            PlatformWorkedWith  \
# Respondent
# 25983       AWS;Docker;Heroku;Linux;MacOS;Raspberry Pi;Win...
# 22013       Android;Arduino;Google Cloud Platform;IBM Clou...
# 28243                           Android;AWS;iOS;MacOS;Windows
# 32250       Android;AWS;Docker;Google Cloud Platform;IBM C...
# 15528                                     Android;iOS;Windows
# 34938            Android;AWS;Docker;iOS;Linux;MacOS;Other(s):
# 539                              AWS;Docker;Linux;MacOS;Slack
# 3873                                                    Linux
# 12625                               Android;AWS;iOS;WordPress
# 36336                                                     NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 25983                          AWS;Docker;Linux;MacOS;Windows
# 22013                             IBM Cloud or Watson;Windows
# 28243                                           Android;Linux
# 32250                                               AWS;Linux
# 15528                                             Android;iOS
# 34938       Google Cloud Platform;IBM Cloud or Watson;Kube...
# 539              AWS;Docker;Google Cloud Platform;Linux;MacOS
# 3873                                  Docker;Kubernetes;Linux
# 12625                                         Android;AWS;iOS
# 36336                                                  Docker
#
#                                WebFrameWorkedWith  \
# Respondent
# 25983                          Angular/Angular.js
# 22013                                      jQuery
# 28243                                         NaN
# 32250             ASP.NET;Express;React.js;Vue.js
# 15528                          Angular/Angular.js
# 34938                              jQuery;Laravel
# 539                        Express;Flask;React.js
# 3873                                     React.js
# 12625       ASP.NET;Express;Flask;React.js;Vue.js
# 36336                   Angular/Angular.js;Spring
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 25983                       Angular/Angular.js;Flask;React.js
# 22013                                                     NaN
# 28243                                                     NaN
# 32250                                                  Vue.js
# 15528                                                     NaN
# 34938       Angular/Angular.js;ASP.NET;Django;Flask;jQuery...
# 539                                            Flask;React.js
# 3873                                                 React.js
# 12625                                        Express;React.js
# 36336                                                     NaN
#
#                                  MiscTechWorkedWith  \
# Respondent
# 25983                        .NET;.NET Core;Node.js
# 22013                                    TensorFlow
# 28243                       Node.js;Pandas;Unity 3D
# 32250                  .NET Core;Node.js;TensorFlow
# 15528                                       Xamarin
# 34938         Node.js;Puppet;Unity 3D;Unreal Engine
# 539         Node.js;Pandas;TensorFlow;Torch/PyTorch
# 3873                                        Node.js
# 12625                          Node.js;React Native
# 36336                                           NaN
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 25983                                       .NET Core;Node.js
# 22013                                              TensorFlow
# 28243                                  Unity 3D;Unreal Engine
# 32250                                                 Node.js
# 15528                                                     NaN
# 34938       Ansible;.NET;Node.js;Puppet;Unity 3D;Unreal En...
# 539                                     Node.js;Torch/PyTorch
# 3873                   Node.js;Pandas;React Native;TensorFlow
# 12625                         Node.js;React Native;TensorFlow
# 36336                                            Apache Spark
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 25983       Notepad++;Sublime Text;Vim;Visual Studio;Visua...      Windows
# 22013                        Visual Studio;Visual Studio Code      Windows
# 28243       Android Studio;Coda;PyCharm;Visual Studio;Visu...        MacOS
# 32250                                      Visual Studio Code  Linux-based
# 15528                                           Visual Studio        MacOS
# 34938       Android Studio;IntelliJ;Notepad++;PHPStorm;Sub...      Windows
# 539                            PyCharm;Vim;Visual Studio Code        MacOS
# 3873                                                     Atom  Linux-based
# 12625             Android Studio;Notepad++;Visual Studio Code      Windows
# 36336                                      IntelliJ;Notepad++      Windows
#
#                                                    Containers  \
# Respondent
# 25983                                  Development;Production
# 22013                                             Development
# 28243                                 I do not use containers
# 32250       Development;Testing;Production;Outside of work...
# 15528                                                 Testing
# 34938       Development;Testing;Production;Outside of work...
# 539                            Development;Testing;Production
# 3873                                              Development
# 12625                                 I do not use containers
# 36336                                 I do not use containers
#
#                                       BlockchainOrg  \
# Respondent
# 25983                                           NaN
# 22013           Implementing our own cryptocurrency
# 28243                                           NaN
# 32250                                           NaN
# 15528                                    Not at all
# 34938       Non-currency applications of blockchain
# 539                                      Not at all
# 3873                                     Not at all
# 12625                                    Not at all
# 36336                                    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 25983       Useful for decentralized currency (i.e., Bitcoin)         No
# 22013       Useful across many domains and could change ma...        Yes
# 28243                       An irresponsible use of resources         No
# 32250       Useful across many domains and could change ma...        Yes
# 15528       Useful for decentralized currency (i.e., Bitcoin)        Yes
# 34938       Useful across many domains and could change ma...         No
# 539                                             A passing fad         No
# 3873        Useful for immutable record keeping outside of...        Yes
# 12625                                                     NaN         No
# 36336       Useful across many domains and could change ma...        Yes
#
#             ITperson OffOn               SocialMedia  \
# Respondent
# 25983            Yes   Yes                    Reddit
# 22013            Yes    No                   YouTube
# 28243            Yes    No  I don't use social media
# 32250       Also Yes   Yes                   Twitter
# 15528            Yes   Yes                    Reddit
# 34938            Yes   Yes                    Reddit
# 539         Also Yes   Yes                    Reddit
# 3873             Yes   Yes                    Reddit
# 12625       Also Yes   Yes                    Reddit
# 36336            Yes   Yes                   YouTube
#
#                         Extraversion   ScreenName        SOVisit1st  \
# Respondent
# 25983       In real life (in person)     Username              2013
# 22013                         Online  Screen Name               NaN
# 28243       In real life (in person)     Username              2008
# 32250                         Online          NaN              2008
# 15528                         Online     Username              2014
# 34938       In real life (in person)          NaN              2009
# 539         In real life (in person)     Username  I don't remember
# 3873        In real life (in person)     Username              2012
# 12625       In real life (in person)     Username              2011
# 36336       In real life (in person)     Username              2011
#
#                                 SOVisitFreq  \
# Respondent
# 25983                 Daily or almost daily
# 22013                  A few times per week
# 28243                 Daily or almost daily
# 32250                  A few times per week
# 15528                 Daily or almost daily
# 34938                 Daily or almost daily
# 539                   Daily or almost daily
# 3873        A few times per month or weekly
# 12625                 Daily or almost daily
# 36336                 Daily or almost daily
#
#                                                     SOVisitTo  \
# Respondent
# 25983       Find answers to specific questions;Learn how t...
# 22013                      Find answers to specific questions
# 28243                      Find answers to specific questions
# 32250       Find answers to specific questions;Learn how t...
# 15528       Find answers to specific questions;Learn how t...
# 34938       Find answers to specific questions;Learn how t...
# 539         Find answers to specific questions;Learn how t...
# 3873        Find answers to specific questions;Pass the ti...
# 12625       Find answers to specific questions;Learn how t...
# 36336       Find answers to specific questions;Learn how t...
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 25983                1-2 times per week      Stack Overflow was much faster
# 22013                1-2 times per week      Stack Overflow was much faster
# 28243       More than 10 times per week      Stack Overflow was much faster
# 32250           Less than once per week      Stack Overflow was much faster
# 15528               6-10 times per week      Stack Overflow was much faster
# 34938               6-10 times per week      Stack Overflow was much faster
# 539                  3-5 times per week      Stack Overflow was much faster
# 3873            Less than once per week  Stack Overflow was slightly faster
# 12625                3-5 times per week            They were about the same
# 36336                3-5 times per week      Stack Overflow was much faster
#
#             SOHowMuchTime                  SOAccount  \
# Respondent
# 25983       11-30 minutes                        Yes
# 22013         60+ minutes                        Yes
# 28243         60+ minutes                        Yes
# 32250       11-30 minutes                        Yes
# 15528       11-30 minutes                        Yes
# 34938       11-30 minutes                        Yes
# 539          0-10 minutes                        Yes
# 3873         0-10 minutes                        Yes
# 12625                 NaN                         No
# 36336       11-30 minutes  Not sure / can't remember
#
#                                                    SOPartFreq  \
# Respondent
# 25983                     Less than once per month or monthly
# 22013       I have never participated in Q&A on Stack Over...
# 28243                                  Multiple times per day
# 32250                                    A few times per week
# 15528                         A few times per month or weekly
# 34938                                    A few times per week
# 539         I have never participated in Q&A on Stack Over...
# 3873                      Less than once per month or monthly
# 12625                                                     NaN
# 36336                                                     NaN
#
#                                                        SOJobs  \
# Respondent
# 25983       No, I knew that Stack Overflow had a job board...
# 22013                                                     Yes
# 28243                                                     Yes
# 32250       No, I knew that Stack Overflow had a job board...
# 15528                                                     Yes
# 34938                                                     Yes
# 539         No, I knew that Stack Overflow had a job board...
# 3873                                                      Yes
# 12625                                                     Yes
# 36336       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 25983                     No, and I don't know what those are
# 22013                                                     Yes
# 28243                     No, and I don't know what those are
# 32250       No, I've heard of them, but I am not part of a...
# 15528                     No, and I don't know what those are
# 34938       No, I've heard of them, but I am not part of a...
# 539                       No, and I don't know what those are
# 3873        No, I've heard of them, but I am not part of a...
# 12625       No, I've heard of them, but I am not part of a...
# 36336                     No, and I don't know what those are
#
#                      SOComm                             WelcomeChange  \
# Respondent
# 25983        No, not really   Just as welcome now as I felt last year
# 22013       Yes, definitely     A lot more welcome now than last year
# 28243       Yes, definitely     A lot less welcome now than last year
# 32250         Yes, somewhat   Just as welcome now as I felt last year
# 15528               Neutral  Somewhat more welcome now than last year
# 34938       Yes, definitely   Just as welcome now as I felt last year
# 539          No, not really   Just as welcome now as I felt last year
# 3873          Yes, somewhat   Just as welcome now as I felt last year
# 12625               Neutral   Just as welcome now as I felt last year
# 36336               Neutral   Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 25983                                                     NaN  24.0    Man
# 22013       Tech articles written by other developers;Indu...   NaN    Man
# 28243                     Tech meetups or events in your area   NaN    NaN
# 32250       Industry news about technologies you're intere...  30.0    Man
# 15528       Tech articles written by other developers;Cour...  31.0    Man
# 34938       Tech articles written by other developers;Indu...  43.0    Man
# 539              Courses on technologies you're interested in  40.0    Man
# 3873                      Tech meetups or events in your area  24.0    Man
# 12625                                                     NaN  26.0    Man
# 36336            Courses on technologies you're interested in   NaN    NaN
#
#            Trans                Sexuality                     Ethnicity  \
# Respondent
# 25983         No  Straight / Heterosexual  White or of European descent
# 22013         No  Straight / Heterosexual                           NaN
# 28243        NaN  Straight / Heterosexual                           NaN
# 32250         No  Straight / Heterosexual  White or of European descent
# 15528         No  Straight / Heterosexual  White or of European descent
# 34938         No  Straight / Heterosexual  White or of European descent
# 539           No  Straight / Heterosexual  White or of European descent
# 3873          No  Straight / Heterosexual  White or of European descent
# 12625         No  Straight / Heterosexual  White or of European descent
# 36336        NaN  Straight / Heterosexual  White or of European descent
#
#            Dependents           SurveyLength                  SurveyEase
# Respondent
# 25983              No  Appropriate in length                        Easy
# 22013             Yes               Too long                        Easy
# 28243             Yes              Too short                        Easy
# 32250              No  Appropriate in length                        Easy
# 15528              No  Appropriate in length                        Easy
# 34938             Yes  Appropriate in length                        Easy
# 539               Yes  Appropriate in length                        Easy
# 3873               No               Too long                        Easy
# 12625              No  Appropriate in length  Neither easy nor difficult
# 36336              No               Too long                        Easy

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 32250    2000000.0
# 15528    2000000.0
# 34938    2000000.0
# 539      2000000.0
# 3873     2000000.0
# 12625    2000000.0
# 36336    2000000.0
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# ### `DataFrame.nsmallest(<n>, <column>)` and `Series.nsmallest(<n>)` methods

# %% [markdown]
# The `.nsmallest()` methods work just like the `.nlargest()` methods, but return the *n* smallest values in a `DataFrame` or `Series`.

# %% [markdown]
# Note: All the `.nlargest()` and `.nsmallest()` methods shown above just return the corresponding `DataFrame` or `Series` object, and have to be reassigned in case you want to store the returned result.
