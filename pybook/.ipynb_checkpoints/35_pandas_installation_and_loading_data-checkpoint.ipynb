# %% [markdown]
# # Pandas: Installation and loading data
#
# Pandas stands for “Python Data Analysis Library”.
#
# Pandas is quite a game changer when it comes to analyzing data with Python and it is one of the most preferred and widely used tools in data munging/wrangling if not THE most used one.
#
# What’s cool about Pandas is that it takes data (like a CSV or TSV file, or a SQL database) and creates a Python object with rows and columns called data frame that looks very similar to table in a statistical software (think Excel or SPSS for example). This is so much easier to work with in comparison to working with lists and/or dictionaries through for loops or list comprehensions.
#
# By convention, the **pandas** library is always imported as **pd**

# %%
import pandas as pd

# %% [markdown]
# `pandas.read_csv()` *method* us used to read a comma-separated values (csv) file into DataFrame.

# %%
df = pd.read_csv('work_directory/pandas/data/survey_results_public.csv')

# %% [markdown]
# By default, a data frame in Jupyter Notebook, is returned for visualization in the notebook with a *maximum of 20 columns*, and also, with the *rows being concatenated.*
#
# This default value can be changed by using `pd.set_option('display.max_columns', 85)` as shown later in this notebook.

# %%
df
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 0             1             I am a student who is learning to code      Yes
# 1             2             I am a student who is learning to code       No
# 2             3  I am not primarily a developer, but I write co...      Yes
# 3             4                     I am a developer by profession       No
# 4             5                     I am a developer by profession      Yes
# ..          ...                                                ...      ...
# 992         996             I am a student who is learning to code      Yes
# 993         997                     I am a developer by profession       No
# 994         998             I am a student who is learning to code      Yes
# 995         999                     I am a developer by profession      Yes
# 996        1000                     I am a developer by profession      Yes
#
#                                            OpenSourcer  \
# 0                                                Never
# 1                              Less than once per year
# 2                                                Never
# 3                                                Never
# 4                           Once a month or more often
# ..                                                 ...
# 992                         Once a month or more often
# 993                                              Never
# 994                            Less than once per year
# 995                            Less than once per year
# 996  Less than once a month but more than once per ...
#
#                                             OpenSource  \
# 0    The quality of OSS and closed source software ...
# 1    The quality of OSS and closed source software ...
# 2    The quality of OSS and closed source software ...
# 3    The quality of OSS and closed source software ...
# 4    OSS is, on average, of HIGHER quality than pro...
# ..                                                 ...
# 992  The quality of OSS and closed source software ...
# 993  The quality of OSS and closed source software ...
# 994  OSS is, on average, of HIGHER quality than pro...
# 995  OSS is, on average, of HIGHER quality than pro...
# 996  OSS is, on average, of HIGHER quality than pro...
#
#                                             Employment  \
# 0               Not employed, and not looking for work
# 1                   Not employed, but looking for work
# 2                                   Employed full-time
# 3                                   Employed full-time
# 4                                   Employed full-time
# ..                                                 ...
# 992             Not employed, and not looking for work
# 993                                 Employed full-time
# 994             Not employed, and not looking for work
# 995  Independent contractor, freelancer, or self-em...
# 996                                 Employed part-time
#
#                     Country         Student  \
# 0            United Kingdom              No
# 1    Bosnia and Herzegovina  Yes, full-time
# 2                  Thailand              No
# 3             United States              No
# 4                   Ukraine              No
# ..                      ...             ...
# 992          United Kingdom  Yes, full-time
# 993          United Kingdom              No
# 994                   India              No
# 995                   Spain              No
# 996             Netherlands              No
#
#                                                EdLevel  \
# 0                            Primary/elementary school
# 1    Secondary school (e.g. American high school, G...
# 2             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4             Bachelor’s degree (BA, BS, B.Eng., etc.)
# ..                                                 ...
# 992  Some college/university study without earning ...
# 993           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 994  Secondary school (e.g. American high school, G...
# 995           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 996           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                         UndergradMajor  ...  \
# 0                                                  NaN  ...
# 1                                                  NaN  ...
# 2                        Web development or web design  ...
# 3    Computer science, computer engineering, or sof...  ...
# 4    Computer science, computer engineering, or sof...  ...
# ..                                                 ...  ...
# 992  Computer science, computer engineering, or sof...  ...
# 993  Computer science, computer engineering, or sof...  ...
# 994                                                NaN  ...
# 995  Information systems, information technology, o...  ...
# 996                                                NaN  ...
#
#                                 WelcomeChange  \
# 0     Just as welcome now as I felt last year
# 1     Just as welcome now as I felt last year
# 2     Just as welcome now as I felt last year
# 3     Just as welcome now as I felt last year
# 4     Just as welcome now as I felt last year
# ..                                        ...
# 992   Just as welcome now as I felt last year
# 993     A lot less welcome now than last year
# 994   Just as welcome now as I felt last year
# 995  Somewhat more welcome now than last year
# 996  Somewhat more welcome now than last year
#
#                                           SONewContent   Age Gender Trans  \
# 0    Tech articles written by other developers;Indu...  14.0    Man    No
# 1    Tech articles written by other developers;Indu...  19.0    Man    No
# 2    Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3    Tech articles written by other developers;Indu...  22.0    Man    No
# 4    Tech meetups or events in your area;Courses on...  30.0    Man    No
# ..                                                 ...   ...    ...   ...
# 992                Tech meetups or events in your area  18.0    NaN    No
# 993       Courses on technologies you're interested in  25.0  Woman    No
# 994  Industry news about technologies you're intere...   NaN    Man    No
# 995  Tech articles written by other developers;Tech...  28.0    Man    No
# 996  Industry news about technologies you're intere...  25.0    Man    No
#
#                    Sexuality                                 Ethnicity  \
# 0    Straight / Heterosexual                                       NaN
# 1    Straight / Heterosexual                                       NaN
# 2    Straight / Heterosexual                                       NaN
# 3    Straight / Heterosexual              White or of European descent
# 4    Straight / Heterosexual  White or of European descent;Multiracial
# ..                       ...                                       ...
# 992  Straight / Heterosexual                                       NaN
# 993  Straight / Heterosexual              White or of European descent
# 994  Straight / Heterosexual                                       NaN
# 995  Straight / Heterosexual                 Hispanic or Latino/Latina
# 996  Straight / Heterosexual              White or of European descent
#
#     Dependents           SurveyLength                  SurveyEase
# 0           No  Appropriate in length  Neither easy nor difficult
# 1           No  Appropriate in length  Neither easy nor difficult
# 2          Yes  Appropriate in length  Neither easy nor difficult
# 3           No  Appropriate in length                        Easy
# 4           No  Appropriate in length                        Easy
# ..         ...                    ...                         ...
# 992         No  Appropriate in length                        Easy
# 993         No  Appropriate in length  Neither easy nor difficult
# 994         No  Appropriate in length                        Easy
# 995        Yes  Appropriate in length                        Easy
# 996         No  Appropriate in length                        Easy
#
# [997 rows x 85 columns]

# %% [markdown]
# `pandas.DataFrame.head()` *method* returns the first *n* rows (default = 5) for the object based on position.<br> It is useful for quickly testing if your object has the right type of data in it.
#
# `pandas.DataFrame.tail()` *method* does the same, as above, but for the end of the data frame.

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %% [markdown]
# `pandas.DataFrame.shape` is an *attribute* that returns a *tuple* of the number of rows and columns, i.e. *(#rows, #columns)*

# %%
df.shape
# Out:
# (997, 85)

# %% [markdown]
# `pandas.DataFrame.info()` is a *method* that gives us the data types for all the columns, alongwith the number if rows and columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              997 non-null    int64
#  1   MainBranch              997 non-null    object
#  2   Hobbyist                997 non-null    object
#  3   OpenSourcer             997 non-null    object
#  4   OpenSource              979 non-null    object
#  5   Employment              971 non-null    object
#  6   Country                 997 non-null    object
#  7   Student                 977 non-null    object
#  8   EdLevel                 973 non-null    object
#  9   UndergradMajor          842 non-null    object
#  10  EduOther                947 non-null    object
#  11  OrgSize                 814 non-null    object
#  12  DevType                 923 non-null    object
#  13  YearsCode               991 non-null    object
#  14  Age1stCode              985 non-null    object
#  15  YearsCodePro            842 non-null    object
#  16  CareerSat               831 non-null    object
#  17  JobSat                  816 non-null    object
#  18  MgrIdiot                692 non-null    object
#  19  MgrMoney                692 non-null    object
#  20  MgrWant                 692 non-null    object
#  21  JobSeek                 922 non-null    object
#  22  LastHireDate            918 non-null    object
#  23  LastInt                 760 non-null    object
#  24  FizzBuzz                815 non-null    object
#  25  JobFactors              912 non-null    object
#  26  ResumeUpdate            888 non-null    object
#  27  CurrencySymbol          817 non-null    object
#  28  CurrencyDesc            817 non-null    object
#  29  CompTotal               648 non-null    float64
#  30  CompFreq                726 non-null    object
#  31  ConvertedComp           645 non-null    float64
#  32  WorkWeekHrs             737 non-null    float64
#  33  WorkPlan                793 non-null    object
#  34  WorkChallenge           779 non-null    object
#  35  WorkRemote              807 non-null    object
#  36  WorkLoc                 804 non-null    object
#  37  ImpSyn                  820 non-null    object
#  38  CodeRev                 810 non-null    object
#  39  CodeRevHrs              588 non-null    float64
#  40  UnitTests               717 non-null    object
#  41  PurchaseHow             701 non-null    object
#  42  PurchaseWhat            711 non-null    object
#  43  LanguageWorkedWith      986 non-null    object
#  44  LanguageDesireNextYear  951 non-null    object
#  45  DatabaseWorkedWith      848 non-null    object
#  46  DatabaseDesireNextYear  762 non-null    object
#  47  PlatformWorkedWith      913 non-null    object
#  48  PlatformDesireNextYear  872 non-null    object
#  49  WebFrameWorkedWith      743 non-null    object
#  50  WebFrameDesireNextYear  707 non-null    object
#  51  MiscTechWorkedWith      662 non-null    object
#  52  MiscTechDesireNextYear  730 non-null    object
#  53  DevEnviron              983 non-null    object
#  54  OpSys                   991 non-null    object
#  55  Containers              963 non-null    object
#  56  BlockchainOrg           565 non-null    object
#  57  BlockchainIs            670 non-null    object
#  58  BetterLife              967 non-null    object
#  59  ITperson                981 non-null    object
#  60  OffOn                   973 non-null    object
#  61  SocialMedia             953 non-null    object
#  62  Extraversion            978 non-null    object
#  63  ScreenName              888 non-null    object
#  64  SOVisit1st              944 non-null    object
#  65  SOVisitFreq             992 non-null    object
#  66  SOVisitTo               988 non-null    object
#  67  SOFindAnswer            988 non-null    object
#  68  SOTimeSaved             968 non-null    object
#  69  SOHowMuchTime           779 non-null    object
#  70  SOAccount               986 non-null    object
#  71  SOPartFreq              835 non-null    object
#  72  SOJobs                  991 non-null    object
#  73  EntTeams                988 non-null    object
#  74  SOComm                  991 non-null    object
#  75  WelcomeChange           963 non-null    object
#  76  SONewContent            775 non-null    object
#  77  Age                     902 non-null    float64
#  78  Gender                  957 non-null    object
#  79  Trans                   942 non-null    object
#  80  Sexuality               861 non-null    object
#  81  Ethnicity               859 non-null    object
#  82  Dependents              944 non-null    object
#  83  SurveyLength            975 non-null    object
#  84  SurveyEase              975 non-null    object
# dtypes: float64(5), int64(1), object(79)
# memory usage: 662.2+ KB

# %%
pd.set_option('display.max_columns', 85)

# %%
df
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 0             1             I am a student who is learning to code      Yes
# 1             2             I am a student who is learning to code       No
# 2             3  I am not primarily a developer, but I write co...      Yes
# 3             4                     I am a developer by profession       No
# 4             5                     I am a developer by profession      Yes
# ..          ...                                                ...      ...
# 992         996             I am a student who is learning to code      Yes
# 993         997                     I am a developer by profession       No
# 994         998             I am a student who is learning to code      Yes
# 995         999                     I am a developer by profession      Yes
# 996        1000                     I am a developer by profession      Yes
#
#                                            OpenSourcer  \
# 0                                                Never
# 1                              Less than once per year
# 2                                                Never
# 3                                                Never
# 4                           Once a month or more often
# ..                                                 ...
# 992                         Once a month or more often
# 993                                              Never
# 994                            Less than once per year
# 995                            Less than once per year
# 996  Less than once a month but more than once per ...
#
#                                             OpenSource  \
# 0    The quality of OSS and closed source software ...
# 1    The quality of OSS and closed source software ...
# 2    The quality of OSS and closed source software ...
# 3    The quality of OSS and closed source software ...
# 4    OSS is, on average, of HIGHER quality than pro...
# ..                                                 ...
# 992  The quality of OSS and closed source software ...
# 993  The quality of OSS and closed source software ...
# 994  OSS is, on average, of HIGHER quality than pro...
# 995  OSS is, on average, of HIGHER quality than pro...
# 996  OSS is, on average, of HIGHER quality than pro...
#
#                                             Employment  \
# 0               Not employed, and not looking for work
# 1                   Not employed, but looking for work
# 2                                   Employed full-time
# 3                                   Employed full-time
# 4                                   Employed full-time
# ..                                                 ...
# 992             Not employed, and not looking for work
# 993                                 Employed full-time
# 994             Not employed, and not looking for work
# 995  Independent contractor, freelancer, or self-em...
# 996                                 Employed part-time
#
#                     Country         Student  \
# 0            United Kingdom              No
# 1    Bosnia and Herzegovina  Yes, full-time
# 2                  Thailand              No
# 3             United States              No
# 4                   Ukraine              No
# ..                      ...             ...
# 992          United Kingdom  Yes, full-time
# 993          United Kingdom              No
# 994                   India              No
# 995                   Spain              No
# 996             Netherlands              No
#
#                                                EdLevel  \
# 0                            Primary/elementary school
# 1    Secondary school (e.g. American high school, G...
# 2             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4             Bachelor’s degree (BA, BS, B.Eng., etc.)
# ..                                                 ...
# 992  Some college/university study without earning ...
# 993           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 994  Secondary school (e.g. American high school, G...
# 995           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 996           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                         UndergradMajor  \
# 0                                                  NaN
# 1                                                  NaN
# 2                        Web development or web design
# 3    Computer science, computer engineering, or sof...
# 4    Computer science, computer engineering, or sof...
# ..                                                 ...
# 992  Computer science, computer engineering, or sof...
# 993  Computer science, computer engineering, or sof...
# 994                                                NaN
# 995  Information systems, information technology, o...
# 996                                                NaN
#
#                                               EduOther  \
# 0    Taught yourself a new language, framework, or ...
# 1    Taken an online course in programming or softw...
# 2    Taught yourself a new language, framework, or ...
# 3    Taken an online course in programming or softw...
# 4    Taken an online course in programming or softw...
# ..                                                 ...
# 992  Taken an online course in programming or softw...
# 993  Taken an online course in programming or softw...
# 994  Taken an online course in programming or softw...
# 995  Taught yourself a new language, framework, or ...
# 996  Taken an online course in programming or softw...
#
#                       OrgSize  \
# 0                         NaN
# 1                         NaN
# 2        100 to 499 employees
# 3        100 to 499 employees
# 4    10,000 or more employees
# ..                        ...
# 992                       NaN
# 993      100 to 499 employees
# 994                       NaN
# 995  5,000 to 9,999 employees
# 996             2-9 employees
#
#                                                DevType YearsCode Age1stCode  \
# 0                                                  NaN         4         10
# 1    Developer, desktop or enterprise applications;...       NaN         17
# 2    Designer;Developer, back-end;Developer, front-...         3         22
# 3                                Developer, full-stack         3         16
# 4    Academic researcher;Developer, desktop or ente...        16         14
# ..                                                 ...       ...        ...
# 992                                                NaN         7         11
# 993                                     Engineer, data         7         12
# 994                                                NaN         3         10
# 995  Academic researcher;Developer, back-end;Develo...         8         20
# 996  Developer, front-end;Developer, full-stack;Dev...        10         10
#
#          YearsCodePro           CareerSat                 JobSat  \
# 0                 NaN                 NaN                    NaN
# 1                 NaN                 NaN                    NaN
# 2                   1  Slightly satisfied     Slightly satisfied
# 3    Less than 1 year      Very satisfied     Slightly satisfied
# 4                   9   Very dissatisfied  Slightly dissatisfied
# ..                ...                 ...                    ...
# 992               NaN                 NaN                    NaN
# 993                 3  Slightly satisfied      Very dissatisfied
# 994               NaN                 NaN                    NaN
# 995                 6  Slightly satisfied         Very satisfied
# 996                 3  Slightly satisfied     Slightly satisfied
#
#                  MgrIdiot  MgrMoney   MgrWant  \
# 0                     NaN       NaN       NaN
# 1                     NaN       NaN       NaN
# 2    Not at all confident  Not sure  Not sure
# 3          Very confident        No  Not sure
# 4      Somewhat confident       Yes        No
# ..                    ...       ...       ...
# 992                   NaN       NaN       NaN
# 993  Not at all confident       Yes        No
# 994                   NaN       NaN       NaN
# 995                   NaN       NaN       NaN
# 996    Somewhat confident        No       Yes
#
#                                                JobSeek          LastHireDate  \
# 0                                                  NaN                   NaN
# 1                      I am actively looking for a job  I've never had a job
# 2    I’m not actively looking, but I am open to new...         1-2 years ago
# 3         I am not interested in new job opportunities  Less than a year ago
# 4         I am not interested in new job opportunities  Less than a year ago
# ..                                                 ...                   ...
# 992                                                NaN                   NaN
# 993                    I am actively looking for a job  Less than a year ago
# 994                                                NaN                   NaN
# 995  I’m not actively looking, but I am open to new...         1-2 years ago
# 996       I am not interested in new job opportunities         3-4 years ago
#
#                                                LastInt FizzBuzz  \
# 0                                                  NaN      NaN
# 1                                                  NaN      NaN
# 2                  Interview with people in peer roles       No
# 3    Write code by hand (e.g., on a whiteboard);Int...       No
# 4    Write any code;Write code by hand (e.g., on a ...       No
# ..                                                 ...      ...
# 992                                                NaN      NaN
# 993  Write any code;Write code by hand (e.g., on a ...      Yes
# 994                                                NaN      NaN
# 995  Write any code;Write code by hand (e.g., on a ...       No
# 996  Write any code;Interview with people in peer r...       No
#
#                                             JobFactors  \
# 0                                                  NaN
# 1    Financial performance or funding status of the...
# 2    Languages, frameworks, and other technologies ...
# 3    Languages, frameworks, and other technologies ...
# 4    Industry that I'd be working in;Languages, fra...
# ..                                                 ...
# 992                                                NaN
# 993  Specific department or team I'd be working on;...
# 994                                                NaN
# 995  Industry that I'd be working in;Financial perf...
# 996  Languages, frameworks, and other technologies ...
#
#                                           ResumeUpdate CurrencySymbol  \
# 0                                                  NaN            NaN
# 1    Something else changed (education, award, medi...            NaN
# 2                     I was preparing for a job search            THB
# 3                     I was preparing for a job search            USD
# 4                     I was preparing for a job search            UAH
# ..                                                 ...            ...
# 992                                                NaN            NaN
# 993                   I was preparing for a job search            GBP
# 994                                                NaN            NaN
# 995  Something else changed (education, award, medi...            USD
# 996  I heard about a job opportunity (from a recrui...            EUR
#
#              CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                     NaN        NaN      NaN            NaN          NaN
# 1                     NaN        NaN      NaN            NaN          NaN
# 2               Thai baht    23000.0  Monthly         8820.0         40.0
# 3    United States dollar    61000.0   Yearly        61000.0         80.0
# 4       Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ..                    ...        ...      ...            ...          ...
# 992                   NaN        NaN      NaN            NaN          NaN
# 993        Pound sterling    55000.0   Yearly        71966.0         36.0
# 994                   NaN        NaN      NaN            NaN          NaN
# 995  United States dollar     2125.0   Weekly       106250.0         40.0
# 996         European Euro    23192.0  Monthly       318864.0         32.0
#
#                                               WorkPlan  \
# 0                                                  NaN
# 1                                                  NaN
# 2    There's no schedule or spec; I work on what se...
# 3    There's no schedule or spec; I work on what se...
# 4    There is a schedule and/or spec (made by me or...
# ..                                                 ...
# 992                                                NaN
# 993  There's no schedule or spec; I work on what se...
# 994                                                NaN
# 995  There is a schedule and/or spec (made by me or...
# 996  There is a schedule and/or spec (made by me or...
#
#                                          WorkChallenge  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Distracting work environment;Inadequate access...
# 3                                                  NaN
# 4    Being tasked with non-development work;Inadequ...
# ..                                                 ...
# 992                                                NaN
# 993  Being tasked with non-development work;Distrac...
# 994                                                NaN
# 995  Meetings;Non-work commitments (parenting, scho...
# 996  Lack of support from management;Meetings;Not e...
#
#                                             WorkRemote WorkLoc  \
# 0                                                  NaN     NaN
# 1                                                  NaN     NaN
# 2                     Less than once per month / Never    Home
# 3                     Less than once per month / Never    Home
# 4                                A few days each month  Office
# ..                                                 ...     ...
# 992                                                NaN     NaN
# 993                              A few days each month  Office
# 994                                                NaN     NaN
# 995  All or almost all the time (I'm full-time remote)    Home
# 996                   Less than once per month / Never  Office
#
#                      ImpSyn                                  CodeRev  \
# 0                       NaN                                      NaN
# 1                       NaN                                      NaN
# 2                   Average                                       No
# 3    A little below average                                       No
# 4    A little above average  Yes, because I see value in code review
# ..                      ...                                      ...
# 992                     NaN                                      NaN
# 993                 Average  Yes, because I see value in code review
# 994                     NaN                                      NaN
# 995  A little above average         Yes, because I was told to do so
# 996  A little above average  Yes, because I see value in code review
#
#      CodeRevHrs                                          UnitTests  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                          No, but I think we should
# 3           NaN                          No, but I think we should
# 4           NaN                      Yes, it's part of our process
# ..          ...                                                ...
# 992         NaN                                                NaN
# 993         1.0  Yes, it's not part of our process but the deve...
# 994         NaN                                                NaN
# 995         6.0                                                NaN
# 996         4.0                          No, but I think we should
#
#                                            PurchaseHow  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                             Not sure
# 3    Developers typically have the most influence o...
# 4                                             Not sure
# ..                                                 ...
# 992                                                NaN
# 993                                           Not sure
# 994                                                NaN
# 995                                                NaN
# 996  Developers typically have the most influence o...
#
#                       PurchaseWhat  \
# 0                              NaN
# 1                              NaN
# 2    I have little or no influence
# 3    I have little or no influence
# 4    I have little or no influence
# ..                             ...
# 992                            NaN
# 993  I have little or no influence
# 994                            NaN
# 995                            NaN
# 996          I have some influence
#
#                                     LanguageWorkedWith  \
# 0                      HTML/CSS;Java;JavaScript;Python
# 1                                  C++;HTML/CSS;Python
# 2                                             HTML/CSS
# 3                                  C;C++;C#;Python;SQL
# 4          C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ..                                                 ...
# 992  Assembly;Bash/Shell/PowerShell;C;HTML/CSS;Java...
# 993                   Bash/Shell/PowerShell;Python;SQL
# 994  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 995                HTML/CSS;Java;JavaScript;Python;SQL
# 996  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
#
#                                 LanguageDesireNextYear  \
# 0      C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                          C++;HTML/CSS;JavaScript;SQL
# 2                                      Elixir;HTML/CSS
# 3                                  C;C#;JavaScript;SQL
# 4             HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ..                                                 ...
# 992  Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 993             Bash/Shell/PowerShell;Python;Scala;SQL
# 994  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 995                       Java;JavaScript;Kotlin;Swift
# 996             HTML/CSS;JavaScript;Python;WebAssembly
#
#                                    DatabaseWorkedWith  \
# 0                                              SQLite
# 1                                                 NaN
# 2                                          PostgreSQL
# 3                                        MySQL;SQLite
# 4    Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ..                                                ...
# 992                                           MongoDB
# 993                           MySQL;PostgreSQL;SQLite
# 994                                          Firebase
# 995                      Firebase;MariaDB;MySQL;Redis
# 996                               MongoDB;MySQL;Redis
#
#                                 DatabaseDesireNextYear  \
# 0                                                MySQL
# 1                                                MySQL
# 2                                           PostgreSQL
# 3                                         MySQL;SQLite
# 4    Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ..                                                 ...
# 992                                   DynamoDB;MongoDB
# 993    Cassandra;Elasticsearch;MySQL;PostgreSQL;SQLite
# 994                                           Firebase
# 995  Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 996                                      MongoDB;MySQL
#
#                                    PlatformWorkedWith  \
# 0                                       MacOS;Windows
# 1                                             Windows
# 2                                                 NaN
# 3                                       Linux;Windows
# 4                   Android;Linux;MacOS;Slack;Windows
# ..                                                ...
# 992                               Android;Arduino;AWS
# 993                         AWS;Google Cloud Platform
# 994  Arduino;Google Cloud Platform;Linux;Raspberry Pi
# 995       Android;Docker;Heroku;iOS;Linux;MacOS;Slack
# 996                       Docker;Heroku;iOS;WordPress
#
#                                 PlatformDesireNextYear  \
# 0                              Android;Arduino;Windows
# 1                                              Windows
# 2                                                  NaN
# 3                                        Linux;Windows
# 4                Android;Docker;Kubernetes;Linux;Slack
# ..                                                 ...
# 992                         Android;Arduino;AWS;Docker
# 993                                                AWS
# 994                         Arduino;Linux;Raspberry Pi
# 995  Android;AWS;Docker;Heroku;iOS;Kubernetes;Linux...
# 996                        Docker;Heroku;iOS;WordPress
#
#                               WebFrameWorkedWith  \
# 0                                   Django;Flask
# 1                                         Django
# 2                                            NaN
# 3                                            NaN
# 4    Django;Express;Flask;jQuery;React.js;Spring
# ..                                           ...
# 992                              jQuery;React.js
# 993                                          NaN
# 994                                        Flask
# 995                      Express;React.js;Spring
# 996                      Express;jQuery;React.js
#
#            WebFrameDesireNextYear            MiscTechWorkedWith  \
# 0                    Flask;jQuery                       Node.js
# 1                          Django                           NaN
# 2                       Other(s):                           NaN
# 3                             NaN                          .NET
# 4    Flask;jQuery;React.js;Spring               Cordova;Node.js
# ..                            ...                           ...
# 992                      React.js                           NaN
# 993                           NaN           Apache Spark;Hadoop
# 994                         Flask                           NaN
# 995       Express;React.js;Spring          Node.js;React Native
# 996              Express;React.js  Ansible;Node.js;React Native
#
#                                 MiscTechDesireNextYear  \
# 0                                              Node.js
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 .NET
# 4             Apache Spark;Hadoop;Node.js;React Native
# ..                                                 ...
# 992                            React Native;TensorFlow
# 993                                Apache Spark;Hadoop
# 994                                                NaN
# 995  Apache Spark;Hadoop;Node.js;Pandas;Puppet;Reac...
# 996                Ansible;Node.js;Pandas;React Native
#
#                                             DevEnviron        OpSys  \
# 0                           IntelliJ;Notepad++;PyCharm      Windows
# 1                                         Atom;PyCharm      Windows
# 2                               Vim;Visual Studio Code  Linux-based
# 3         Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                               IntelliJ;Notepad++;Vim  Linux-based
# ..                                                 ...          ...
# 992  Android Studio;Atom;IntelliJ;Sublime Text;Visu...      Windows
# 993                           PyCharm;Sublime Text;Vim        MacOS
# 994           Android Studio;Atom;Eclipse;Sublime Text  Linux-based
# 995                            IntelliJ;PHPStorm;Xcode        MacOS
# 996                                 Sublime Text;Xcode        MacOS
#
#                                  Containers BlockchainOrg  \
# 0                   I do not use containers           NaN
# 1                   I do not use containers           NaN
# 2                   I do not use containers           NaN
# 3                   I do not use containers    Not at all
# 4    Outside of work, for personal projects    Not at all
# ..                                      ...           ...
# 992                 I do not use containers           NaN
# 993  Outside of work, for personal projects    Not at all
# 994                 I do not use containers           NaN
# 995          Development;Testing;Production           NaN
# 996          Development;Testing;Production    Not at all
#
#                                           BlockchainIs BetterLife  \
# 0                                                  NaN        Yes
# 1    Useful across many domains and could change ma...        Yes
# 2                                                  NaN        Yes
# 3    Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                  NaN        Yes
# ..                                                 ...        ...
# 992  Useful for immutable record keeping outside of...         No
# 993                                                NaN        Yes
# 994  Useful across many domains and could change ma...        Yes
# 995  Useful across many domains and could change ma...         No
# 996                                                NaN        Yes
#
#                                      ITperson OffOn SocialMedia  \
# 0    Fortunately, someone else has that title   Yes     Twitter
# 1                                         Yes   Yes   Instagram
# 2                                         Yes   Yes      Reddit
# 3                                        SIGH   Yes      Reddit
# 4                                    Also Yes   Yes    Facebook
# ..                                        ...   ...         ...
# 992                                      SIGH   Yes    WhatsApp
# 993                                       NaN   NaN    LinkedIn
# 994                                       Yes   Yes   Instagram
# 995                                       Yes   Yes     YouTube
# 996  Fortunately, someone else has that title   Yes    Facebook
#
#                  Extraversion ScreenName        SOVisit1st  \
# 0                      Online   Username              2017
# 1                      Online   Username              2017
# 2    In real life (in person)   Username              2011
# 3    In real life (in person)   Username              2014
# 4    In real life (in person)   Username  I don't remember
# ..                        ...        ...               ...
# 992                   Neither   Username  I don't remember
# 993  In real life (in person)   Username  I don't remember
# 994  In real life (in person)   Username  I don't remember
# 995  In real life (in person)   Username              2008
# 996                    Online   Username              2015
#
#                          SOVisitFreq  \
# 0    A few times per month or weekly
# 1              Daily or almost daily
# 2               A few times per week
# 3              Daily or almost daily
# 4             Multiple times per day
# ..                               ...
# 992  A few times per month or weekly
# 993           Multiple times per day
# 994            Daily or almost daily
# 995           Multiple times per day
# 996            Daily or almost daily
#
#                                              SOVisitTo  \
# 0    Find answers to specific questions;Learn how t...
# 1    Find answers to specific questions;Learn how t...
# 2    Find answers to specific questions;Learn how t...
# 3    Find answers to specific questions;Pass the ti...
# 4                   Find answers to specific questions
# ..                                                 ...
# 992  Find answers to specific questions;Learn how t...
# 993                 Find answers to specific questions
# 994  Find answers to specific questions;Learn how t...
# 995  Find answers to specific questions;Learn how t...
# 996  Find answers to specific questions;Contribute ...
#
#                     SOFindAnswer                         SOTimeSaved  \
# 0             3-5 times per week      Stack Overflow was much faster
# 1             3-5 times per week      Stack Overflow was much faster
# 2            6-10 times per week            They were about the same
# 3             1-2 times per week      Stack Overflow was much faster
# 4    More than 10 times per week      Stack Overflow was much faster
# ..                           ...                                 ...
# 992      Less than once per week      Stack Overflow was much faster
# 993  More than 10 times per week            They were about the same
# 994           1-2 times per week  Stack Overflow was slightly faster
# 995          6-10 times per week      Stack Overflow was much faster
# 996           1-2 times per week      Stack Overflow was much faster
#
#      SOHowMuchTime SOAccount                           SOPartFreq  \
# 0    31-60 minutes        No                                  NaN
# 1    11-30 minutes       Yes      A few times per month or weekly
# 2              NaN       Yes  Less than once per month or monthly
# 3    31-60 minutes       Yes  Less than once per month or monthly
# 4              NaN       Yes      A few times per month or weekly
# ..             ...       ...                                  ...
# 992  11-30 minutes       Yes  Less than once per month or monthly
# 993            NaN       Yes  Less than once per month or monthly
# 994  11-30 minutes       Yes                 A few times per week
# 995  31-60 minutes       Yes  Less than once per month or monthly
# 996    60+ minutes       Yes                Daily or almost daily
#
#                                                 SOJobs  \
# 0    No, I didn't know that Stack Overflow had a jo...
# 1    No, I knew that Stack Overflow had a job board...
# 2                                                  Yes
# 3                                                  Yes
# 4    No, I knew that Stack Overflow had a job board...
# ..                                                 ...
# 992  No, I knew that Stack Overflow had a job board...
# 993                                                Yes
# 994  No, I knew that Stack Overflow had a job board...
# 995                                                Yes
# 996                                                Yes
#
#                                               EntTeams           SOComm  \
# 0                  No, and I don't know what those are          Neutral
# 1                  No, and I don't know what those are    Yes, somewhat
# 2    No, I've heard of them, but I am not part of a...          Neutral
# 3                  No, and I don't know what those are   No, not really
# 4    No, I've heard of them, but I am not part of a...  Yes, definitely
# ..                                                 ...              ...
# 992  No, I've heard of them, but I am not part of a...          Neutral
# 993  No, I've heard of them, but I am not part of a...   No, not at all
# 994  No, I've heard of them, but I am not part of a...    Yes, somewhat
# 995                No, and I don't know what those are   No, not really
# 996  No, I've heard of them, but I am not part of a...  Yes, definitely
#
#                                 WelcomeChange  \
# 0     Just as welcome now as I felt last year
# 1     Just as welcome now as I felt last year
# 2     Just as welcome now as I felt last year
# 3     Just as welcome now as I felt last year
# 4     Just as welcome now as I felt last year
# ..                                        ...
# 992   Just as welcome now as I felt last year
# 993     A lot less welcome now than last year
# 994   Just as welcome now as I felt last year
# 995  Somewhat more welcome now than last year
# 996  Somewhat more welcome now than last year
#
#                                           SONewContent   Age Gender Trans  \
# 0    Tech articles written by other developers;Indu...  14.0    Man    No
# 1    Tech articles written by other developers;Indu...  19.0    Man    No
# 2    Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3    Tech articles written by other developers;Indu...  22.0    Man    No
# 4    Tech meetups or events in your area;Courses on...  30.0    Man    No
# ..                                                 ...   ...    ...   ...
# 992                Tech meetups or events in your area  18.0    NaN    No
# 993       Courses on technologies you're interested in  25.0  Woman    No
# 994  Industry news about technologies you're intere...   NaN    Man    No
# 995  Tech articles written by other developers;Tech...  28.0    Man    No
# 996  Industry news about technologies you're intere...  25.0    Man    No
#
#                    Sexuality                                 Ethnicity  \
# 0    Straight / Heterosexual                                       NaN
# 1    Straight / Heterosexual                                       NaN
# 2    Straight / Heterosexual                                       NaN
# 3    Straight / Heterosexual              White or of European descent
# 4    Straight / Heterosexual  White or of European descent;Multiracial
# ..                       ...                                       ...
# 992  Straight / Heterosexual                                       NaN
# 993  Straight / Heterosexual              White or of European descent
# 994  Straight / Heterosexual                                       NaN
# 995  Straight / Heterosexual                 Hispanic or Latino/Latina
# 996  Straight / Heterosexual              White or of European descent
#
#     Dependents           SurveyLength                  SurveyEase
# 0           No  Appropriate in length  Neither easy nor difficult
# 1           No  Appropriate in length  Neither easy nor difficult
# 2          Yes  Appropriate in length  Neither easy nor difficult
# 3           No  Appropriate in length                        Easy
# 4           No  Appropriate in length                        Easy
# ..         ...                    ...                         ...
# 992         No  Appropriate in length                        Easy
# 993         No  Appropriate in length  Neither easy nor difficult
# 994         No  Appropriate in length                        Easy
# 995        Yes  Appropriate in length                        Easy
# 996         No  Appropriate in length                        Easy
#
# [997 rows x 85 columns]

# %% [markdown]
# The **survey_results_schema file.csv** in the data folder gives the matching questions for each of the columns in the data frame we have read.

# %%
df_schema = pd.read_csv('work_directory/pandas/data/survey_results_schema.csv')

# %%
df_schema
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %% [markdown]
# Notice how not all the rows are visible above.

# %%
pd.set_option('display.max_rows', 85)

# %%
df_schema
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# 11                 OrgSize  Approximately how many people are employed by ...
# 12                 DevType  Which of the following describe you? Please se...
# 13               YearsCode  Including any education, how many years have y...
# 14              Age1stCode  At what age did you write your first line of c...
# 15            YearsCodePro  How many years have you coded professionally (...
# 16               CareerSat  Overall, how satisfied are you with your caree...
# 17                  JobSat  How satisfied are you with your current job? (...
# 18                MgrIdiot  How confident are you that your manager knows ...
# 19                MgrMoney  Do you believe that you need to be a manager t...
# 20                 MgrWant  Do you want to become a manager yourself in th...
# 21                 JobSeek  Which of the following best describes your cur...
# 22            LastHireDate  When was the last time that you took a job wit...
# 23                 LastInt  In your most recent successful job interview (...
# 24                FizzBuzz  Have you ever been asked to solve FizzBuzz in ...
# 25              JobFactors  Imagine that you are deciding between two job ...
# 26            ResumeUpdate  Think back to the last time you updated your r...
# 27          CurrencySymbol  Which currency do you use day-to-day? If your ...
# 28            CurrencyDesc  Which currency do you use day-to-day? If your ...
# 29               CompTotal  What is your current total compensation (salar...
# 30                CompFreq   Is that compensation weekly, monthly, or yearly?
# 31           ConvertedComp  Salary converted to annual USD salaries using ...
# 32             WorkWeekHrs   On average, how many hours per week do you work?
# 33                WorkPlan            How structured or planned is your work?
# 34           WorkChallenge  Of these options, what are your greatest chall...
# 35              WorkRemote                    How often do you work remotely?
# 36                 WorkLoc                    Where would you prefer to work?
# 37                  ImpSyn  For the specific work you do, and the years of...
# 38                 CodeRev           Do you review code as part of your work?
# 39              CodeRevHrs  On average, how many hours per week do you spe...
# 40               UnitTests  Does your company regularly employ unit tests ...
# 41             PurchaseHow  How does your company make decisions about pur...
# 42            PurchaseWhat  What level of influence do you, personally, ha...
# 43      LanguageWorkedWith  Which of the following programming, scripting,...
# 44  LanguageDesireNextYear  Which of the following programming, scripting,...
# 45      DatabaseWorkedWith  Which of the following database environments h...
# 46  DatabaseDesireNextYear  Which of the following database environments h...
# 47      PlatformWorkedWith  Which of the following platforms have you done...
# 48  PlatformDesireNextYear  Which of the following platforms have you done...
# 49      WebFrameWorkedWith  Which of the following web frameworks have you...
# 50  WebFrameDesireNextYear  Which of the following web frameworks have you...
# 51      MiscTechWorkedWith  Which of the following other frameworks, libra...
# 52  MiscTechDesireNextYear  Which of the following other frameworks, libra...
# 53              DevEnviron  Which development environment(s) do you use re...
# 54                   OpSys  What is the primary operating system in which ...
# 55              Containers  How do you use containers (Docker, Open Contai...
# 56           BlockchainOrg  How is your organization thinking about or imp...
# 57            BlockchainIs  Blockchain / cryptocurrency technology is prim...
# 58              BetterLife  Do you think people born today will have a bet...
# 59                ITperson   Are you the "IT support person" for your family?
# 60                   OffOn        Have you tried turning it off and on again?
# 61             SocialMedia        What social media site do you use the most?
# 62            Extraversion    Do you prefer online chat or IRL conversations?
# 63              ScreenName                               What do you call it?
# 64              SOVisit1st  To the best of your memory, when did you first...
# 65             SOVisitFreq  How frequently would you say you visit Stack O...
# 66               SOVisitTo  I visit Stack Overflow to... (check all that a...
# 67            SOFindAnswer  On average, how many times a week do you find ...
# 68             SOTimeSaved  Think back to the last time you solved a codin...
# 69           SOHowMuchTime  About how much time did you save? If you're no...
# 70               SOAccount              Do you have a Stack Overflow account?
# 71              SOPartFreq  How frequently would you say you participate i...
# 72                  SOJobs  Have you ever used or visited Stack Overflow J...
# 73                EntTeams  Have you ever used Stack Overflow for Enterpri...
# 74                  SOComm  Do you consider yourself a member of the Stack...
# 75           WelcomeChange  Compared to last year, how welcome do you feel...
# 76            SONewContent  Would you like to see any of the following on ...
# 77                     Age  What is your age (in years)? If you prefer not...
# 78                  Gender  Which of the following do you currently identi...
# 79                   Trans                    Do you identify as transgender?
# 80               Sexuality  Which of the following do you currently identi...
# 81               Ethnicity  Which of the following do you identify as? Ple...
# 82              Dependents  Do you have any dependents (e.g., children, el...
# 83            SurveyLength  How do you feel about the length of the survey...
# 84              SurveyEase  How easy or difficult was this survey to compl...
